# %%
import sys, os, argparse, glob, pathlib, time
import subprocess

import numpy as np
from tqdm import tqdm
from skimage.filters import gaussian
from skimage import io
import tifffile as tif
from segmentation.training.ctc_training_set import create_ctc_training_set

# %%
create_ctc_training_set("/disk1/neurips/dataset/train_labeled")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /disk1/t_scherr-cell-segmentation-and-tracking-e44acc0fdb8d/distance_neighbour_representation.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B131.114.51.35/disk1/t_scherr-cell-segmentation-and-tracking-e44acc0fdb8d/distance_neighbour_representation.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> create_ctc_training_set("/disk1/neurips/dataset/train_labeled")
#
# File /disk1/t_scherr-cell-segmentation-and-tracking-e44acc0fdb8d/segmentation/training/ctc_training_set.py:212, in create_ctc_training_set(path)
#     187 """ Create the CTC Training Set.
#     188
#     189 :param path: Path to the directory containing the Cell Tracking Challenge data.
#     190     :type path: Path
#     191 :return: None
#     192 """
#     194 # Create directories
# ...

# %%
#instance mask
import matplotlib.pyplot as plt
plt.imshow(lbl[0])

# %%
#binary mask
plt.imshow(lbl[1])

# %%
#bd
plt.imshow(lbl[2])

# %%
#dist
plt.imshow(lbl[3])

# %%
#weight
plt.imshow(lbl[4])

# %%
plt.imshow(lbl[5])

# %%
plt.imshow(lbl[6])

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/instance_labels/cell_00001_label.tif'))

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/binary_labels/cell_00001_label.tif'))

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/boundery_labels/cell_00001_label.tif'))

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/distance_labels/cell_00001_label.tif'))

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/weight_labels/cell_00001_label.tif'))

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/flow1_labels/cell_00001_label.tif'))

# %%
plt.imshow(tif.imread('/disk1/neurips/dataset/train_omnipese_4class/flow2_labels/cell_00001_label.tif'))
